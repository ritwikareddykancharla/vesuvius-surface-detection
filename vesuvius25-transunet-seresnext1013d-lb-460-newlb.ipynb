# %% [markdown]
# <h1 style="color: #6cb4e4;  text-align: center;  padding: 0.25em;  border-top: solid 2.5px #6cb4e4;  border-bottom: solid 2.5px #6cb4e4;  background: -webkit-repeating-linear-gradient(-45deg, #f0f8ff, #f0f8ff 3px,#e9f4ff 3px, #e9f4ff 7px);  background: repeating-linear-gradient(-45deg, #f0f8ff, #f0f8ff 3px,#e9f4ff 3px, #e9f4ff 7px);height:45px;">
# <b>
# OnlyInfKernel
# </b></h1>

# %% [markdown]
# ### **ℹ️INFO**
# * First, I want to thank you for sharing such a strong baseline.
#     * [@INNAT, LB.507, Vesuvius Surface 3D Detection](https://www.kaggle.com/code/ipythonx/inference-vesuvius-surface-3d-detection?scriptVersionId=285843716)
#
# ### **ℹ️[LB.454 2025/12/26]MyUpdate**(※Please note that this model was trained on data before the Dataset update on Dec 23, 2025)
# * Results of improving the models and train pipeline available in medic-ai.
# * Since good CV/LB was obtained, we will share the model weights together.
#     * **Model: TransUNet**
#     * **Encoder: SEResNeXt1013D**
#     * **Local Validation(DiceScore): .7685**
#     * **Public LB: .454**
#         * ↑My TrainModel Weight↑:https://www.kaggle.com/datasets/hideyukizushi/colab-a-162v5-gpu-transunet-seresnext101-x160
#         * ※Training was performed on Google Colaboratory using GPU A100 (80GB).
#
# ### **ℹ️[LB.460 2025/12/31]MyUpdate**(※Please note that this model was trained on data before the Dataset update on Dec 23, 2025)
# * The Public LB dataset has been updated, reference I am publishing the model that produced my score.
#     * **Model: TransUNet**
#     * **Encoder: SEResNeXt1013D**
#     * **Local Validation(DiceScore): .7679**
#     * **Public LB: .460**
#         * ↑My TrainModel Weight↑:https://www.kaggle.com/datasets/hideyukizushi/colab-a-162v4-gpu-transunet-seresnext101-x160

# %%
var="/kaggle/input/vesuvius25-packages-offline-installer-v20251226/whls"
# !pip install \
    "$var"/keras_nightly-3.12.0.dev2025100703-py3-none-any.whl \
    "$var"/tifffile-2025.10.16-py3-none-any.whl \
    "$var"/imagecodecs-2025.11.11-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl \
    "$var"/medicai-0.0.3-py3-none-any.whl \
    --no-index \
    --find-links "$var"
# Out:
# Looking in links: /kaggle/input/vesuvius25-packages-offline-installer-v20251226/whls
# Processing /kaggle/input/vesuvius25-packages-offline-installer-v20251226/whls/keras_nightly-3.12.0.dev2025100703-py3-none-any.whl
# Processing /kaggle/input/vesuvius25-packages-offline-installer-v20251226/whls/tifffile-2025.10.16-py3-none-any.whl
# Processing /kaggle/input/vesuvius25-packages-offline-installer-v20251226/whls/imagecodecs-2025.11.11-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# Processing /kaggle/input/vesuvius25-packages-offline-installer-v20251226/whls/medicai-0.0.3-py3-none-any.whl
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras-nightly==3.12.0.dev2025100703) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras-nightly==3.12.0.dev2025100703) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras-nightly==3.12.0.dev2025100703) (14.2.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras-nightly==3.12.0.dev2025100703) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras-nightly==3.12.0.dev2025100703) (3.14.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras-nightly==3.12.0.dev2025100703) (0.16.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras-nightly==3.12.0.dev2025100703) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras-nightly==3.12.0.dev2025100703) (25.0)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.11/dist-packages (from medicai==0.0.3) (2.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from medicai==0.0.3) (2.2.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from medicai==0.0.3) (3.7.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from medicai==0.0.3) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from medicai==0.0.3) (2.32.5)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.11/dist-packages (from medicai==0.0.3) (4.4.4)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from medicai==0.0.3) (4.15.0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from medicai==0.0.3) (2025.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from medicai==0.0.3) (2.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from medicai==0.0.3) (1.15.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from medicai==0.0.3) (4.67.1)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.11/dist-packages (from medicai==0.0.3) (5.3.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->keras-nightly==3.12.0.dev2025100703) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->keras-nightly==3.12.0.dev2025100703) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->keras-nightly==3.12.0.dev2025100703) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->keras-nightly==3.12.0.dev2025100703) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->keras-nightly==3.12.0.dev2025100703) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->keras-nightly==3.12.0.dev2025100703) (2.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->medicai==0.0.3) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->medicai==0.0.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->medicai==0.0.3) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->medicai==0.0.3) (1.4.8)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->medicai==0.0.3) (11.3.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->medicai==0.0.3) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->medicai==0.0.3) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.11/dist-packages (from nibabel->medicai==0.0.3) (6.5.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf->medicai==0.0.3) (4.9.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->medicai==0.0.3) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->medicai==0.0.3) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->medicai==0.0.3) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->medicai==0.0.3) (2025.10.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras-nightly==3.12.0.dev2025100703) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras-nightly==3.12.0.dev2025100703) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras-nightly==3.12.0.dev2025100703) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->medicai==0.0.3) (1.17.0)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->keras-nightly==3.12.0.dev2025100703) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->keras-nightly==3.12.0.dev2025100703) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->keras-nightly==3.12.0.dev2025100703) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->keras-nightly==3.12.0.dev2025100703) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->keras-nightly==3.12.0.dev2025100703) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->keras-nightly==3.12.0.dev2025100703) (2024.2.0)
# Installing collected packages: tifffile, medicai, keras-nightly, imagecodecs
#   Attempting uninstall: tifffile
#     Found existing installation: tifffile 2025.6.11
#     Uninstalling tifffile-2025.6.11:
#       Successfully uninstalled tifffile-2025.6.11
# Successfully installed imagecodecs-2025.11.11 keras-nightly-3.12.0.dev2025100703 medicai-0.0.3 tifffile-2025.10.16

# %% [markdown]
# <h1 style="color: #6cb4e4;  text-align: center;  padding: 0.25em;  border-top: solid 2.5px #6cb4e4;  border-bottom: solid 2.5px #6cb4e4;  background: -webkit-repeating-linear-gradient(-45deg, #f0f8ff, #f0f8ff 3px,#e9f4ff 3px, #e9f4ff 7px);  background: repeating-linear-gradient(-45deg, #f0f8ff, #f0f8ff 3px,#e9f4ff 3px, #e9f4ff 7px);height:45px;">
# <b>
# Model Detail
# </b></h1>

# %% [markdown]
# * List of models available on MedicAI

# %%
import warnings
warnings.simplefilter('ignore')

import medicai
medicai.models.list_models()
# Out:
# 2025-12-31 08:44:47.676121: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767170687.864510      20 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767170687.915289      20 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
#                    Model Registry Catalog
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Segmentor        ┃ Backbone Family ┃ Variants             ┃
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━┩
# │ • attention_unet │ convnext        │ • convnext_base      │
# │ • deeplabv3plus  │                 │ • convnext_large     │
# │ • unet           │                 │ • convnext_small     │
# │ • unet_plus_plus │                 │ • convnext_tiny      │
# │ • upernet        │                 │ • convnext_v2_atto   │
# │                  │                 │ • convnext_v2_base   │
# │                  │                 │ • convnext_v2_femto  │
# │                  │                 │ • convnext_v2_huge   │
# │                  │                 │ • convnext_v2_large  │
# │                  │                 │ • convnext_v2_nano   │
# │                  │                 │ • convnext_v2_pico   │
# │                  │                 │ • convnext_v2_small  │
# │                  │                 │ • convnext_v2_tiny   │
# │                  │                 │ • convnext_xlarge    │
# ├──────────────────┼─────────────────┼──────────────────────┤
# │ • attention_unet │ densenet        │ • densenet121        │
# │ • deeplabv3plus  │                 │ • densenet169        │
# │ • trans_unet     │                 │ • densenet201        │
# │ • unet           │                 │ • densenet264        │
# │ • unet_plus_plus │                 │                      │
# │ • upernet        │                 │                      │
# ├──────────────────┼─────────────────┼──────────────────────┤
# │ • attention_unet │ efficientnet    │ • efficientnet_b0    │
# │ • deeplabv3plus  │                 │ • efficientnet_b1    │
# │ • trans_unet     │                 │ • efficientnet_b2    │
# │ • unet           │                 │ • efficientnet_b3    │
# │ • unet_plus_plus │                 │ • efficientnet_b4    │
# │ • upernet        │                 │ • efficientnet_b5    │
# │                  │                 │ • efficientnet_b6    │
# │                  │                 │ • efficientnet_b7    │
# │                  │                 │ • efficientnet_b8    │
# │                  │                 │ • efficientnet_l2    │
# │                  │                 │ • efficientnet_v2_b0 │
# │                  │                 │ • efficientnet_v2_b1 │
# │                  │                 │ • efficientnet_v2_b2 │
# │                  │                 │ • efficientnet_v2_b3 │
# │                  │                 │ • efficientnet_v2_l  │
# │                  │                 │ • efficientnet_v2_m  │
# │                  │                 │ • efficientnet_v2_s  │
# ├──────────────────┼─────────────────┼──────────────────────┤
# │ • segformer      │ mit             │ • mit_b0             │
# │ • upernet        │                 │ • mit_b1             │
# │                  │                 │ • mit_b2             │
# │                  │                 │ • mit_b3             │
# │                  │                 │ • mit_b4             │
# │                  │                 │ • mit_b5             │
# ├──────────────────┼─────────────────┼──────────────────────┤
# │ • attention_unet │ resnet          │ • resnet101          │
# │ • deeplabv3plus  │                 │ • resnet101_v2       │
# │ • trans_unet     │                 │ • resnet152          │
# │ • unet           │                 │ • resnet152_v2       │
# │ • unet_plus_plus │                 │ • resnet18           │
# │ • upernet        │                 │ • resnet200_vd       │
# │                  │                 │ • resnet34           │
# │                  │                 │ • resnet50           │
# │                  │                 │ • resnet50_v2        │
# │                  │                 │ • resnet50_vd        │
# │                  │                 │ • resnext101         │
# │                  │                 │ • resnext50          │
# ├──────────────────┼─────────────────┼──────────────────────┤
# │ • attention_unet │ senet           │ • seresnet101        │
# │ • deeplabv3plus  │                 │ • seresnet101_v2     │
# │ • trans_unet     │                 │ • seresnet152        │
# │ • unet           │                 │ • seresnet152_v2     │
# │ • unet_plus_plus │                 │ • seresnet18         │
# │ • upernet        │                 │ • seresnet200_vd     │
# │                  │                 │ • seresnet34         │
# │                  │                 │ • seresnet50         │
# │                  │                 │ • seresnet50_v2      │
# │                  │                 │ • seresnet50_vd      │
# │                  │                 │ • seresnext101       │
# │                  │                 │ • seresnext50        │
# ├──────────────────┼─────────────────┼──────────────────────┤
# │ • swin_unetr     │ swin            │ • swin_base          │
# │ • upernet        │                 │ • swin_base_v2       │
# │                  │                 │ • swin_small         │
# │                  │                 │ • swin_small_v2      │
# │                  │                 │ • swin_tiny          │
# │                  │                 │ • swin_tiny_v2       │
# ├──────────────────┼─────────────────┼──────────────────────┤
# │ • unetr          │ vit             │ • vit_base           │
# │                  │                 │ • vit_huge           │
# │                  │                 │ • vit_large          │
# ├──────────────────┼─────────────────┼──────────────────────┤
# │ • attention_unet │ xception        │ • xception           │
# │ • trans_unet     │                 │                      │
# │ • unet           │                 │                      │
# │ • unet_plus_plus │                 │                      │
# │ • upernet        │                 │                      │
# └──────────────────┴─────────────────┴──────────────────────┘
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <style>
#
# body {
#     color: #000000;
#     background-color: #ffffff;
# }
# </style>
# </head>
# <body>
#     <pre style="font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><code style="font-family:inherit"></code></pre>
# </body>
# </html>

# %% [markdown]
# * Encoder SEResNeXt1013D Detail

# %%
from medicai.models import SEResNeXt101

tmp_backbone = SEResNeXt101(
    input_shape=(160, 160, 160) + (1,),
    include_top=False
)
tmp_backbone.summary()
# Out:
# I0000 00:00:1767170702.215157      20 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1767170702.215771      20 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "SEResNeXt1013D"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 160, 160,  │          0 │ -                 │
# │ (InputLayer)        │ 160, 1)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 166, 166,  │          0 │ input_layer[0][0] │
# │ (ZeroPadding3D)     │ 166, 1)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv3D) │ (None, 80, 80,    │     21,952 │ conv1_pad[0][0]   │
# │                     │ 80, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 80, 80,    │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 80, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 80, 80,    │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 80, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 82, 82,    │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding3D)     │ 82, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 40, 40,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling3D)      │ 40, 64)           │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_1_co… │ (None, 40, 40,    │     16,384 │ pool1_pool[0][0]  │
# │ (Conv3D)            │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_1_bn  │ (None, 40, 40,    │      1,024 │ stack0_block0_1_… │
# │ (BatchNormalizatio… │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_1_re… │ (None, 40, 40,    │          0 │ stack0_block0_1_… │
# │ (Activation)        │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_2_co… │ (None, 40, 40,    │     55,296 │ stack0_block0_1_… │
# │ (Conv3D)            │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_2_bn  │ (None, 40, 40,    │      1,024 │ stack0_block0_2_… │
# │ (BatchNormalizatio… │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_2_re… │ (None, 40, 40,    │          0 │ stack0_block0_2_… │
# │ (Activation)        │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_3_co… │ (None, 40, 40,    │     65,536 │ stack0_block0_2_… │
# │ (Conv3D)            │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_0_co… │ (None, 40, 40,    │     16,384 │ pool1_pool[0][0]  │
# │ (Conv3D)            │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_sque… │ (None, 40, 40,    │      8,464 │ stack0_block0_3_… │
# │ (SqueezeExcitation) │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_0_bn  │ (None, 40, 40,    │      1,024 │ stack0_block0_0_… │
# │ (BatchNormalizatio… │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_3_bn  │ (None, 40, 40,    │      1,024 │ stack0_block0_sq… │
# │ (BatchNormalizatio… │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_add   │ (None, 40, 40,    │          0 │ stack0_block0_0_… │
# │ (Add)               │ 40, 256)          │            │ stack0_block0_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block0_out   │ (None, 40, 40,    │          0 │ stack0_block0_ad… │
# │ (Activation)        │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_1_co… │ (None, 40, 40,    │     65,536 │ stack0_block0_ou… │
# │ (Conv3D)            │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_1_bn  │ (None, 40, 40,    │      1,024 │ stack0_block1_1_… │
# │ (BatchNormalizatio… │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_1_re… │ (None, 40, 40,    │          0 │ stack0_block1_1_… │
# │ (Activation)        │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_2_co… │ (None, 40, 40,    │     55,296 │ stack0_block1_1_… │
# │ (Conv3D)            │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_2_bn  │ (None, 40, 40,    │      1,024 │ stack0_block1_2_… │
# │ (BatchNormalizatio… │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_2_re… │ (None, 40, 40,    │          0 │ stack0_block1_2_… │
# │ (Activation)        │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_3_co… │ (None, 40, 40,    │     65,536 │ stack0_block1_2_… │
# │ (Conv3D)            │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_sque… │ (None, 40, 40,    │      8,464 │ stack0_block1_3_… │
# │ (SqueezeExcitation) │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_3_bn  │ (None, 40, 40,    │      1,024 │ stack0_block1_sq… │
# │ (BatchNormalizatio… │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_add   │ (None, 40, 40,    │          0 │ stack0_block0_ou… │
# │ (Add)               │ 40, 256)          │            │ stack0_block1_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block1_out   │ (None, 40, 40,    │          0 │ stack0_block1_ad… │
# │ (Activation)        │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_1_co… │ (None, 40, 40,    │     65,536 │ stack0_block1_ou… │
# │ (Conv3D)            │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_1_bn  │ (None, 40, 40,    │      1,024 │ stack0_block2_1_… │
# │ (BatchNormalizatio… │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_1_re… │ (None, 40, 40,    │          0 │ stack0_block2_1_… │
# │ (Activation)        │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_2_co… │ (None, 40, 40,    │     55,296 │ stack0_block2_1_… │
# │ (Conv3D)            │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_2_bn  │ (None, 40, 40,    │      1,024 │ stack0_block2_2_… │
# │ (BatchNormalizatio… │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_2_re… │ (None, 40, 40,    │          0 │ stack0_block2_2_… │
# │ (Activation)        │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_3_co… │ (None, 40, 40,    │     65,536 │ stack0_block2_2_… │
# │ (Conv3D)            │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_sque… │ (None, 40, 40,    │      8,464 │ stack0_block2_3_… │
# │ (SqueezeExcitation) │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_3_bn  │ (None, 40, 40,    │      1,024 │ stack0_block2_sq… │
# │ (BatchNormalizatio… │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_add   │ (None, 40, 40,    │          0 │ stack0_block1_ou… │
# │ (Add)               │ 40, 256)          │            │ stack0_block2_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack0_block2_out   │ (None, 40, 40,    │          0 │ stack0_block2_ad… │
# │ (Activation)        │ 40, 256)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_1_co… │ (None, 40, 40,    │    131,072 │ stack0_block2_ou… │
# │ (Conv3D)            │ 40, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_1_bn  │ (None, 40, 40,    │      2,048 │ stack1_block0_1_… │
# │ (BatchNormalizatio… │ 40, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_1_re… │ (None, 40, 40,    │          0 │ stack1_block0_1_… │
# │ (Activation)        │ 40, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_2_pad │ (None, 42, 42,    │          0 │ stack1_block0_1_… │
# │ (ZeroPadding3D)     │ 42, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_2_co… │ (None, 20, 20,    │    221,184 │ stack1_block0_2_… │
# │ (Conv3D)            │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_2_bn  │ (None, 20, 20,    │      2,048 │ stack1_block0_2_… │
# │ (BatchNormalizatio… │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_2_re… │ (None, 20, 20,    │          0 │ stack1_block0_2_… │
# │ (Activation)        │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_3_co… │ (None, 20, 20,    │    262,144 │ stack1_block0_2_… │
# │ (Conv3D)            │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_0_co… │ (None, 20, 20,    │    131,072 │ stack0_block2_ou… │
# │ (Conv3D)            │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_sque… │ (None, 20, 20,    │     33,312 │ stack1_block0_3_… │
# │ (SqueezeExcitation) │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_0_bn  │ (None, 20, 20,    │      2,048 │ stack1_block0_0_… │
# │ (BatchNormalizatio… │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_3_bn  │ (None, 20, 20,    │      2,048 │ stack1_block0_sq… │
# │ (BatchNormalizatio… │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_add   │ (None, 20, 20,    │          0 │ stack1_block0_0_… │
# │ (Add)               │ 20, 512)          │            │ stack1_block0_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block0_out   │ (None, 20, 20,    │          0 │ stack1_block0_ad… │
# │ (Activation)        │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_1_co… │ (None, 20, 20,    │    262,144 │ stack1_block0_ou… │
# │ (Conv3D)            │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_1_bn  │ (None, 20, 20,    │      2,048 │ stack1_block1_1_… │
# │ (BatchNormalizatio… │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_1_re… │ (None, 20, 20,    │          0 │ stack1_block1_1_… │
# │ (Activation)        │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_2_co… │ (None, 20, 20,    │    221,184 │ stack1_block1_1_… │
# │ (Conv3D)            │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_2_bn  │ (None, 20, 20,    │      2,048 │ stack1_block1_2_… │
# │ (BatchNormalizatio… │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_2_re… │ (None, 20, 20,    │          0 │ stack1_block1_2_… │
# │ (Activation)        │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_3_co… │ (None, 20, 20,    │    262,144 │ stack1_block1_2_… │
# │ (Conv3D)            │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_sque… │ (None, 20, 20,    │     33,312 │ stack1_block1_3_… │
# │ (SqueezeExcitation) │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_3_bn  │ (None, 20, 20,    │      2,048 │ stack1_block1_sq… │
# │ (BatchNormalizatio… │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_add   │ (None, 20, 20,    │          0 │ stack1_block0_ou… │
# │ (Add)               │ 20, 512)          │            │ stack1_block1_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block1_out   │ (None, 20, 20,    │          0 │ stack1_block1_ad… │
# │ (Activation)        │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_1_co… │ (None, 20, 20,    │    262,144 │ stack1_block1_ou… │
# │ (Conv3D)            │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_1_bn  │ (None, 20, 20,    │      2,048 │ stack1_block2_1_… │
# │ (BatchNormalizatio… │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_1_re… │ (None, 20, 20,    │          0 │ stack1_block2_1_… │
# │ (Activation)        │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_2_co… │ (None, 20, 20,    │    221,184 │ stack1_block2_1_… │
# │ (Conv3D)            │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_2_bn  │ (None, 20, 20,    │      2,048 │ stack1_block2_2_… │
# │ (BatchNormalizatio… │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_2_re… │ (None, 20, 20,    │          0 │ stack1_block2_2_… │
# │ (Activation)        │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_3_co… │ (None, 20, 20,    │    262,144 │ stack1_block2_2_… │
# │ (Conv3D)            │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_sque… │ (None, 20, 20,    │     33,312 │ stack1_block2_3_… │
# │ (SqueezeExcitation) │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_3_bn  │ (None, 20, 20,    │      2,048 │ stack1_block2_sq… │
# │ (BatchNormalizatio… │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_add   │ (None, 20, 20,    │          0 │ stack1_block1_ou… │
# │ (Add)               │ 20, 512)          │            │ stack1_block2_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block2_out   │ (None, 20, 20,    │          0 │ stack1_block2_ad… │
# │ (Activation)        │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_1_co… │ (None, 20, 20,    │    262,144 │ stack1_block2_ou… │
# │ (Conv3D)            │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_1_bn  │ (None, 20, 20,    │      2,048 │ stack1_block3_1_… │
# │ (BatchNormalizatio… │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_1_re… │ (None, 20, 20,    │          0 │ stack1_block3_1_… │
# │ (Activation)        │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_2_co… │ (None, 20, 20,    │    221,184 │ stack1_block3_1_… │
# │ (Conv3D)            │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_2_bn  │ (None, 20, 20,    │      2,048 │ stack1_block3_2_… │
# │ (BatchNormalizatio… │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_2_re… │ (None, 20, 20,    │          0 │ stack1_block3_2_… │
# │ (Activation)        │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_3_co… │ (None, 20, 20,    │    262,144 │ stack1_block3_2_… │
# │ (Conv3D)            │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_sque… │ (None, 20, 20,    │     33,312 │ stack1_block3_3_… │
# │ (SqueezeExcitation) │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_3_bn  │ (None, 20, 20,    │      2,048 │ stack1_block3_sq… │
# │ (BatchNormalizatio… │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_add   │ (None, 20, 20,    │          0 │ stack1_block2_ou… │
# │ (Add)               │ 20, 512)          │            │ stack1_block3_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack1_block3_out   │ (None, 20, 20,    │          0 │ stack1_block3_ad… │
# │ (Activation)        │ 20, 512)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_1_co… │ (None, 20, 20,    │    524,288 │ stack1_block3_ou… │
# │ (Conv3D)            │ 20, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_1_bn  │ (None, 20, 20,    │      4,096 │ stack2_block0_1_… │
# │ (BatchNormalizatio… │ 20, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_1_re… │ (None, 20, 20,    │          0 │ stack2_block0_1_… │
# │ (Activation)        │ 20, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_2_pad │ (None, 22, 22,    │          0 │ stack2_block0_1_… │
# │ (ZeroPadding3D)     │ 22, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_2_co… │ (None, 10, 10,    │    884,736 │ stack2_block0_2_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_2_bn  │ (None, 10, 10,    │      4,096 │ stack2_block0_2_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_2_re… │ (None, 10, 10,    │          0 │ stack2_block0_2_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_3_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block0_2_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_0_co… │ (None, 10, 10,    │    524,288 │ stack1_block3_ou… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_sque… │ (None, 10, 10,    │    132,160 │ stack2_block0_3_… │
# │ (SqueezeExcitation) │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_0_bn  │ (None, 10, 10,    │      4,096 │ stack2_block0_0_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_3_bn  │ (None, 10, 10,    │      4,096 │ stack2_block0_sq… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_add   │ (None, 10, 10,    │          0 │ stack2_block0_0_… │
# │ (Add)               │ 10, 1024)         │            │ stack2_block0_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block0_out   │ (None, 10, 10,    │          0 │ stack2_block0_ad… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_1_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block0_ou… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_1_bn  │ (None, 10, 10,    │      4,096 │ stack2_block1_1_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_1_re… │ (None, 10, 10,    │          0 │ stack2_block1_1_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_2_co… │ (None, 10, 10,    │    884,736 │ stack2_block1_1_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_2_bn  │ (None, 10, 10,    │      4,096 │ stack2_block1_2_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_2_re… │ (None, 10, 10,    │          0 │ stack2_block1_2_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_3_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block1_2_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_sque… │ (None, 10, 10,    │    132,160 │ stack2_block1_3_… │
# │ (SqueezeExcitation) │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_3_bn  │ (None, 10, 10,    │      4,096 │ stack2_block1_sq… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_add   │ (None, 10, 10,    │          0 │ stack2_block0_ou… │
# │ (Add)               │ 10, 1024)         │            │ stack2_block1_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block1_out   │ (None, 10, 10,    │          0 │ stack2_block1_ad… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_1_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block1_ou… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_1_bn  │ (None, 10, 10,    │      4,096 │ stack2_block2_1_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_1_re… │ (None, 10, 10,    │          0 │ stack2_block2_1_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_2_co… │ (None, 10, 10,    │    884,736 │ stack2_block2_1_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_2_bn  │ (None, 10, 10,    │      4,096 │ stack2_block2_2_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_2_re… │ (None, 10, 10,    │          0 │ stack2_block2_2_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_3_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block2_2_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_sque… │ (None, 10, 10,    │    132,160 │ stack2_block2_3_… │
# │ (SqueezeExcitation) │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_3_bn  │ (None, 10, 10,    │      4,096 │ stack2_block2_sq… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_add   │ (None, 10, 10,    │          0 │ stack2_block1_ou… │
# │ (Add)               │ 10, 1024)         │            │ stack2_block2_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block2_out   │ (None, 10, 10,    │          0 │ stack2_block2_ad… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_1_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block2_ou… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_1_bn  │ (None, 10, 10,    │      4,096 │ stack2_block3_1_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_1_re… │ (None, 10, 10,    │          0 │ stack2_block3_1_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_2_co… │ (None, 10, 10,    │    884,736 │ stack2_block3_1_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_2_bn  │ (None, 10, 10,    │      4,096 │ stack2_block3_2_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_2_re… │ (None, 10, 10,    │          0 │ stack2_block3_2_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_3_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block3_2_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_sque… │ (None, 10, 10,    │    132,160 │ stack2_block3_3_… │
# │ (SqueezeExcitation) │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_3_bn  │ (None, 10, 10,    │      4,096 │ stack2_block3_sq… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_add   │ (None, 10, 10,    │          0 │ stack2_block2_ou… │
# │ (Add)               │ 10, 1024)         │            │ stack2_block3_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block3_out   │ (None, 10, 10,    │          0 │ stack2_block3_ad… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_1_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block3_ou… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_1_bn  │ (None, 10, 10,    │      4,096 │ stack2_block4_1_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_1_re… │ (None, 10, 10,    │          0 │ stack2_block4_1_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_2_co… │ (None, 10, 10,    │    884,736 │ stack2_block4_1_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_2_bn  │ (None, 10, 10,    │      4,096 │ stack2_block4_2_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_2_re… │ (None, 10, 10,    │          0 │ stack2_block4_2_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_3_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block4_2_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_sque… │ (None, 10, 10,    │    132,160 │ stack2_block4_3_… │
# │ (SqueezeExcitation) │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_3_bn  │ (None, 10, 10,    │      4,096 │ stack2_block4_sq… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_add   │ (None, 10, 10,    │          0 │ stack2_block3_ou… │
# │ (Add)               │ 10, 1024)         │            │ stack2_block4_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block4_out   │ (None, 10, 10,    │          0 │ stack2_block4_ad… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_1_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block4_ou… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_1_bn  │ (None, 10, 10,    │      4,096 │ stack2_block5_1_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_1_re… │ (None, 10, 10,    │          0 │ stack2_block5_1_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_2_co… │ (None, 10, 10,    │    884,736 │ stack2_block5_1_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_2_bn  │ (None, 10, 10,    │      4,096 │ stack2_block5_2_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_2_re… │ (None, 10, 10,    │          0 │ stack2_block5_2_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_3_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block5_2_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_sque… │ (None, 10, 10,    │    132,160 │ stack2_block5_3_… │
# │ (SqueezeExcitation) │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_3_bn  │ (None, 10, 10,    │      4,096 │ stack2_block5_sq… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_add   │ (None, 10, 10,    │          0 │ stack2_block4_ou… │
# │ (Add)               │ 10, 1024)         │            │ stack2_block5_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block5_out   │ (None, 10, 10,    │          0 │ stack2_block5_ad… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block6_1_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block5_ou… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block6_1_bn  │ (None, 10, 10,    │      4,096 │ stack2_block6_1_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block6_1_re… │ (None, 10, 10,    │          0 │ stack2_block6_1_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block6_2_co… │ (None, 10, 10,    │    884,736 │ stack2_block6_1_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block6_2_bn  │ (None, 10, 10,    │      4,096 │ stack2_block6_2_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block6_2_re… │ (None, 10, 10,    │          0 │ stack2_block6_2_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block6_3_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block6_2_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block6_sque… │ (None, 10, 10,    │    132,160 │ stack2_block6_3_… │
# │ (SqueezeExcitation) │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block6_3_bn  │ (None, 10, 10,    │      4,096 │ stack2_block6_sq… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block6_add   │ (None, 10, 10,    │          0 │ stack2_block5_ou… │
# │ (Add)               │ 10, 1024)         │            │ stack2_block6_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block6_out   │ (None, 10, 10,    │          0 │ stack2_block6_ad… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block7_1_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block6_ou… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block7_1_bn  │ (None, 10, 10,    │      4,096 │ stack2_block7_1_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block7_1_re… │ (None, 10, 10,    │          0 │ stack2_block7_1_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block7_2_co… │ (None, 10, 10,    │    884,736 │ stack2_block7_1_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block7_2_bn  │ (None, 10, 10,    │      4,096 │ stack2_block7_2_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block7_2_re… │ (None, 10, 10,    │          0 │ stack2_block7_2_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block7_3_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block7_2_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block7_sque… │ (None, 10, 10,    │    132,160 │ stack2_block7_3_… │
# │ (SqueezeExcitation) │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block7_3_bn  │ (None, 10, 10,    │      4,096 │ stack2_block7_sq… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block7_add   │ (None, 10, 10,    │          0 │ stack2_block6_ou… │
# │ (Add)               │ 10, 1024)         │            │ stack2_block7_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block7_out   │ (None, 10, 10,    │          0 │ stack2_block7_ad… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block8_1_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block7_ou… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block8_1_bn  │ (None, 10, 10,    │      4,096 │ stack2_block8_1_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block8_1_re… │ (None, 10, 10,    │          0 │ stack2_block8_1_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block8_2_co… │ (None, 10, 10,    │    884,736 │ stack2_block8_1_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block8_2_bn  │ (None, 10, 10,    │      4,096 │ stack2_block8_2_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block8_2_re… │ (None, 10, 10,    │          0 │ stack2_block8_2_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block8_3_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block8_2_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block8_sque… │ (None, 10, 10,    │    132,160 │ stack2_block8_3_… │
# │ (SqueezeExcitation) │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block8_3_bn  │ (None, 10, 10,    │      4,096 │ stack2_block8_sq… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block8_add   │ (None, 10, 10,    │          0 │ stack2_block7_ou… │
# │ (Add)               │ 10, 1024)         │            │ stack2_block8_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block8_out   │ (None, 10, 10,    │          0 │ stack2_block8_ad… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block9_1_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block8_ou… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block9_1_bn  │ (None, 10, 10,    │      4,096 │ stack2_block9_1_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block9_1_re… │ (None, 10, 10,    │          0 │ stack2_block9_1_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block9_2_co… │ (None, 10, 10,    │    884,736 │ stack2_block9_1_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block9_2_bn  │ (None, 10, 10,    │      4,096 │ stack2_block9_2_… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block9_2_re… │ (None, 10, 10,    │          0 │ stack2_block9_2_… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block9_3_co… │ (None, 10, 10,    │  1,048,576 │ stack2_block9_2_… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block9_sque… │ (None, 10, 10,    │    132,160 │ stack2_block9_3_… │
# │ (SqueezeExcitation) │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block9_3_bn  │ (None, 10, 10,    │      4,096 │ stack2_block9_sq… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block9_add   │ (None, 10, 10,    │          0 │ stack2_block8_ou… │
# │ (Add)               │ 10, 1024)         │            │ stack2_block9_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block9_out   │ (None, 10, 10,    │          0 │ stack2_block9_ad… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block10_1_c… │ (None, 10, 10,    │  1,048,576 │ stack2_block9_ou… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block10_1_bn │ (None, 10, 10,    │      4,096 │ stack2_block10_1… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block10_1_r… │ (None, 10, 10,    │          0 │ stack2_block10_1… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ...
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block20_1_bn │ (None, 10, 10,    │      4,096 │ stack2_block20_1… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block20_1_r… │ (None, 10, 10,    │          0 │ stack2_block20_1… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block20_2_c… │ (None, 10, 10,    │    884,736 │ stack2_block20_1… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block20_2_bn │ (None, 10, 10,    │      4,096 │ stack2_block20_2… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block20_2_r… │ (None, 10, 10,    │          0 │ stack2_block20_2… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block20_3_c… │ (None, 10, 10,    │  1,048,576 │ stack2_block20_2… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block20_squ… │ (None, 10, 10,    │    132,160 │ stack2_block20_3… │
# │ (SqueezeExcitation) │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block20_3_bn │ (None, 10, 10,    │      4,096 │ stack2_block20_s… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block20_add  │ (None, 10, 10,    │          0 │ stack2_block19_o… │
# │ (Add)               │ 10, 1024)         │            │ stack2_block20_3… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block20_out  │ (None, 10, 10,    │          0 │ stack2_block20_a… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block21_1_c… │ (None, 10, 10,    │  1,048,576 │ stack2_block20_o… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block21_1_bn │ (None, 10, 10,    │      4,096 │ stack2_block21_1… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block21_1_r… │ (None, 10, 10,    │          0 │ stack2_block21_1… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block21_2_c… │ (None, 10, 10,    │    884,736 │ stack2_block21_1… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block21_2_bn │ (None, 10, 10,    │      4,096 │ stack2_block21_2… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block21_2_r… │ (None, 10, 10,    │          0 │ stack2_block21_2… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block21_3_c… │ (None, 10, 10,    │  1,048,576 │ stack2_block21_2… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block21_squ… │ (None, 10, 10,    │    132,160 │ stack2_block21_3… │
# │ (SqueezeExcitation) │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block21_3_bn │ (None, 10, 10,    │      4,096 │ stack2_block21_s… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block21_add  │ (None, 10, 10,    │          0 │ stack2_block20_o… │
# │ (Add)               │ 10, 1024)         │            │ stack2_block21_3… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block21_out  │ (None, 10, 10,    │          0 │ stack2_block21_a… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block22_1_c… │ (None, 10, 10,    │  1,048,576 │ stack2_block21_o… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block22_1_bn │ (None, 10, 10,    │      4,096 │ stack2_block22_1… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block22_1_r… │ (None, 10, 10,    │          0 │ stack2_block22_1… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block22_2_c… │ (None, 10, 10,    │    884,736 │ stack2_block22_1… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block22_2_bn │ (None, 10, 10,    │      4,096 │ stack2_block22_2… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block22_2_r… │ (None, 10, 10,    │          0 │ stack2_block22_2… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block22_3_c… │ (None, 10, 10,    │  1,048,576 │ stack2_block22_2… │
# │ (Conv3D)            │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block22_squ… │ (None, 10, 10,    │    132,160 │ stack2_block22_3… │
# │ (SqueezeExcitation) │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block22_3_bn │ (None, 10, 10,    │      4,096 │ stack2_block22_s… │
# │ (BatchNormalizatio… │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block22_add  │ (None, 10, 10,    │          0 │ stack2_block21_o… │
# │ (Add)               │ 10, 1024)         │            │ stack2_block22_3… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack2_block22_out  │ (None, 10, 10,    │          0 │ stack2_block22_a… │
# │ (Activation)        │ 10, 1024)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_1_co… │ (None, 10, 10,    │  2,097,152 │ stack2_block22_o… │
# │ (Conv3D)            │ 10, 2048)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_1_bn  │ (None, 10, 10,    │      8,192 │ stack3_block0_1_… │
# │ (BatchNormalizatio… │ 10, 2048)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_1_re… │ (None, 10, 10,    │          0 │ stack3_block0_1_… │
# │ (Activation)        │ 10, 2048)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_2_pad │ (None, 12, 12,    │          0 │ stack3_block0_1_… │
# │ (ZeroPadding3D)     │ 12, 2048)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_2_co… │ (None, 5, 5, 5,   │  3,538,944 │ stack3_block0_2_… │
# │ (Conv3D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_2_bn  │ (None, 5, 5, 5,   │      8,192 │ stack3_block0_2_… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_2_re… │ (None, 5, 5, 5,   │          0 │ stack3_block0_2_… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_3_co… │ (None, 5, 5, 5,   │  4,194,304 │ stack3_block0_2_… │
# │ (Conv3D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_0_co… │ (None, 5, 5, 5,   │  2,097,152 │ stack2_block22_o… │
# │ (Conv3D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_sque… │ (None, 5, 5, 5,   │    526,464 │ stack3_block0_3_… │
# │ (SqueezeExcitation) │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_0_bn  │ (None, 5, 5, 5,   │      8,192 │ stack3_block0_0_… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_3_bn  │ (None, 5, 5, 5,   │      8,192 │ stack3_block0_sq… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_add   │ (None, 5, 5, 5,   │          0 │ stack3_block0_0_… │
# │ (Add)               │ 2048)             │            │ stack3_block0_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block0_out   │ (None, 5, 5, 5,   │          0 │ stack3_block0_ad… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_1_co… │ (None, 5, 5, 5,   │  4,194,304 │ stack3_block0_ou… │
# │ (Conv3D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_1_bn  │ (None, 5, 5, 5,   │      8,192 │ stack3_block1_1_… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_1_re… │ (None, 5, 5, 5,   │          0 │ stack3_block1_1_… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_2_co… │ (None, 5, 5, 5,   │  3,538,944 │ stack3_block1_1_… │
# │ (Conv3D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_2_bn  │ (None, 5, 5, 5,   │      8,192 │ stack3_block1_2_… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_2_re… │ (None, 5, 5, 5,   │          0 │ stack3_block1_2_… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_3_co… │ (None, 5, 5, 5,   │  4,194,304 │ stack3_block1_2_… │
# │ (Conv3D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_sque… │ (None, 5, 5, 5,   │    526,464 │ stack3_block1_3_… │
# │ (SqueezeExcitation) │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_3_bn  │ (None, 5, 5, 5,   │      8,192 │ stack3_block1_sq… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_add   │ (None, 5, 5, 5,   │          0 │ stack3_block0_ou… │
# │ (Add)               │ 2048)             │            │ stack3_block1_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block1_out   │ (None, 5, 5, 5,   │          0 │ stack3_block1_ad… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_1_co… │ (None, 5, 5, 5,   │  4,194,304 │ stack3_block1_ou… │
# │ (Conv3D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_1_bn  │ (None, 5, 5, 5,   │      8,192 │ stack3_block2_1_… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_1_re… │ (None, 5, 5, 5,   │          0 │ stack3_block2_1_… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_2_co… │ (None, 5, 5, 5,   │  3,538,944 │ stack3_block2_1_… │
# │ (Conv3D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_2_bn  │ (None, 5, 5, 5,   │      8,192 │ stack3_block2_2_… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_2_re… │ (None, 5, 5, 5,   │          0 │ stack3_block2_2_… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_3_co… │ (None, 5, 5, 5,   │  4,194,304 │ stack3_block2_2_… │
# │ (Conv3D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_sque… │ (None, 5, 5, 5,   │    526,464 │ stack3_block2_3_… │
# │ (SqueezeExcitation) │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_3_bn  │ (None, 5, 5, 5,   │      8,192 │ stack3_block2_sq… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_add   │ (None, 5, 5, 5,   │          0 │ stack3_block1_ou… │
# │ (Add)               │ 2048)             │            │ stack3_block2_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack3_block2_out   │ (None, 5, 5, 5,   │          0 │ stack3_block2_ad… │
# │ (Activation)        │ 2048)             │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 113,079,728 (431.36 MB)
#  Trainable params: 112,876,848 (430.59 MB)
#  Non-trainable params: 202,880 (792.50 KB)

# %% [markdown]
# <h1 style="color: #6cb4e4;  text-align: center;  padding: 0.25em;  border-top: solid 2.5px #6cb4e4;  border-bottom: solid 2.5px #6cb4e4;  background: -webkit-repeating-linear-gradient(-45deg, #f0f8ff, #f0f8ff 3px,#e9f4ff 3px, #e9f4ff 7px);  background: repeating-linear-gradient(-45deg, #f0f8ff, #f0f8ff 3px,#e9f4ff 3px, #e9f4ff 7px);height:45px;">
# <b>
# Main
# </b></h1>

# %% [markdown]
# # 》》》**Libs**

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

import keras
from medicai.transforms import (
    Compose,
    ScaleIntensityRange,
)
from medicai.models import SegFormer, TransUNet
from medicai.utils.inference import SlidingWindowInference

import numpy as np
import pandas as pd
import zipfile
import tifffile
from matplotlib import pyplot as plt

keras.config.backend(), keras.version()
# Out:
# ('tensorflow', '3.12.0.dev2025100703')

# %% [markdown]
# # 》》》**Dataset**

# %%
root_dir = "/kaggle/input/vesuvius-challenge-surface-detection"
test_dir = f"{root_dir}/test_images"
output_dir = "/kaggle/working/submission_masks"
zip_path = "/kaggle/working/submission.zip"
os.makedirs(output_dir, exist_ok=True)

# %%
test_df = pd.read_csv(f"{root_dir}/test.csv")
test_df.head()
# Out:
#         id  scroll_id
# 0  1407735      26002

# %% [markdown]
# # 》》》**Transformation**

# %%
def val_transformation(image):
    data = {"image": image}
    pipeline = Compose([
        ScaleIntensityRange(
            keys=["image"],
            a_min = 0,
            a_max = 255,
            b_min = 0,
            b_max = 1,
            clip = True,
        ),
    ])
    result = pipeline(data)
    return result["image"]

# %% [markdown]
# # 》》》**Load Model**

# %%
def get_model():
    model = TransUNet(
        input_shape=(160, 160, 160, 1),
        encoder_name='seresnext101',
        classifier_activation='softmax',
        num_classes=3,
    )
    model.load_weights(
        f"/kaggle/input/colab-a-162v4-gpu-transunet-seresnext101-x160/model.weights.h5"
    )
    return model

# %%
model = get_model()
model.count_params() / 1e6
# Out:
# 154.71535

# %% [markdown]
# # 》》》**Util**

# %%
swi = SlidingWindowInference(
    model,
    num_classes=3,
    roi_size=(160, 160, 160),
    sw_batch_size=1,
    mode='gaussian',
    overlap=0.52,
)

# %%
def load_volume(path):
    vol = tifffile.imread(path)
    vol = vol.astype(np.float32)
    vol = vol[None, ..., None]
    return vol

def predict(sample):
    mask = swi(sample)
    output = mask.argmax(-1).astype(np.uint8).squeeze()
    return output

# %% [markdown]
# # 》》》**Predict & Submission**

# %%
with zipfile.ZipFile(
    zip_path, "w", compression=zipfile.ZIP_DEFLATED
) as z:
    for image_id in test_df["id"]:
        tif_path = f"{test_dir}/{image_id}.tif"
        
        volume = load_volume(tif_path)
        volume = val_transformation(volume)
        output = predict(volume) 
        
        out_path = f"{output_dir}/{image_id}.tif"
        tifffile.imwrite(out_path, output.astype(np.uint8))

        z.write(out_path, arcname=f"{image_id}.tif")
        os.remove(out_path)

print("Submission ZIP:", zip_path)
# Out:
# Total patch 64:   0%|          | 0/64 [00:00<?, ?it/s]WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767170724.921339      68 service.cc:148] XLA service 0x7c723802acf0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1767170724.922150      68 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1767170724.922170      68 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1767170726.930912      68 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1767170729.894053      68 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1767170730.037947      68 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-31 08:45:35.350210: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[1,512,80,80,80]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[1,64,80,80,80]{4,3,2,1,0}, f32[512,64,1,1,1]{4,3,2,1,0}, f32[512]{0}), window={size=1x1x1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-31 08:45:35.772838: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.422819974s
# Trying algorithm eng0{} for conv (f32[1,512,80,80,80]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[1,64,80,80,80]{4,3,2,1,0}, f32[512,64,1,1,1]{4,3,2,1,0}, f32[512]{0}), window={size=1x1x1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-31 08:45:36.773138: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng13{} for conv (f32[1,512,80,80,80]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[1,64,80,80,80]{4,3,2,1,0}, f32[512,64,1,1,1]{4,3,2,1,0}, f32[512]{0}), window={size=1x1x1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-31 08:45:36.829296: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.056359748s
# Trying algorithm eng13{} for conv (f32[1,512,80,80,80]{4,3,2,1,0}, u8[0]{0}) custom-call(f32[1,64,80,80,80]{4,3,2,1,0}, f32[512,64,1,1,1]{4,3,2,1,0}, f32[512]{0}), window={size=1x1x1}, dim_labels=bf012_oi012->bf012, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# E0000 00:00:1767170738.808522      68 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1767170738.953246      68 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1767170750.572711      68 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Total patch 64: 100%|██████████| 64/64 [01:23<00:00,  1.30s/it]
# Submission ZIP: /kaggle/working/submission.zip
